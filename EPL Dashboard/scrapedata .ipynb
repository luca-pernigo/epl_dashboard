# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux ×86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
page = "https://www.transfermarkt.com/premier-league/startseite/wettbewerb/GB1"
pageTree = requests. get (page, headers=headers)
pageSoup = BeautifulSoup (pageTree. content, 'html.parser')

# %%
pageSoup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script type="text/javascript">
# ...

# %%
TeamList = []
Value=[]

# %%
TeamList = pageSoup.find_all("td", {"class": "rechts"})

# %%
TeamList
# Out:
# [<td class="rechts">€19.48m</td>,
#  <td class="rechts">€10.42bn</td>,
#  <td class="rechts">€43.80m</td>,
#  <td class="rechts"><a href="/manchester-city/kader/verein/281/saison_id/2022" title="Manchester City">€1.05bn</a></td>,
#  <td class="rechts">€31.73m</td>,
#  <td class="rechts"><a href="/chelsea-fc/kader/verein/631/saison_id/2022" title="Chelsea FC">€1.02bn</a></td>,
#  <td class="rechts">€38.70m</td>,
#  <td class="rechts"><a href="/arsenal-fc/kader/verein/11/saison_id/2022" title="Arsenal FC">€890.00m</a></td>,
#  <td class="rechts">€29.30m</td>,
#  <td class="rechts"><a href="/liverpool-fc/kader/verein/31/saison_id/2022" title="Liverpool FC">€879.00m</a></td>,
#  <td class="rechts">€24.87m</td>,
#  <td class="rechts"><a href="/manchester-united/kader/verein/985/saison_id/2022" title="Manchester United">€795.70m</a></td>,
#  <td class="rechts">€27.21m</td>,
# ...

# %%
for i in range(0,len(TeamList)):
    Value.append (TeamList[i].text)

# %%
Value[3:-24:2]
# Out:
# ['€1.05bn',
#  '€1.02bn',
#  '€890.00m',
#  '€879.00m',
#  '€795.70m',
#  '€680.30m',
#  '€494.30m',
#  '€451.50m',
#  '€443.10m',
#  '€437.00m',
#  '€398.70m',
#  '€397.00m',
#  '€358.70m',
#  '€352.90m',
#  '€332.65m',
#  '€318.10m',
#  '€318.00m',
#  '€309.95m',
#  '€253.50m',
#  '€243.70m']
