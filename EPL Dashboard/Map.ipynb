# %%
import numpy as np
import pandas as pd
import bokeh
from bokeh.io import curdoc, show, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, Grid, ImageURL, LinearAxis, Plot, Range1d, Select, Column, RangeTool, BoxSelectTool
from bokeh.models import ColumnDataSource, FactorRange, BoxSelectTool, CategoricalColorMapper,Tabs,TabPanel
from bokeh.layouts import column, row, grid
from bokeh.models import ColumnDataSource, FixedTicker
output_notebook()
from bokeh.models import Div
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import curdoc
from bokeh.models import Div

html_file_path = 'heat.html'

with open(html_file_path, 'r') as f:
    html_content = f.read()

div = Div(text=f"<iframe srcdoc='{html_content}'style='min-width:calc(30vw - 26px); height: 300px'><iframe>")

curdoc().add_root(div)

# %%
show(div)
# Out:
#   <div id="7158efce-8cb2-453e-9ffb-d1c03ff6f751" data-root-id="p1002" style="display: contents;"></div>

# %%
# layout = column(heat)
# curdoc().add_root(layout)

# %%
# !bokeh serve --show Untitled.ipynb
# Out:
# 2023-05-17 08:26:25,556 Starting Bokeh server version 3.0.3 (running on Tornado 6.2)
# 2023-05-17 08:26:26,145 User authentication hooks NOT provided (default user enabled)
# 2023-05-17 08:26:26,149 Bokeh app running at: http://localhost:5006/Untitled
# 2023-05-17 08:26:26,149 Starting Bokeh server with process id: 74776
# 2023-05-17 08:26:26,426 /Users/luca/Desktop/group-3/EPL Dashboard/Untitled.ipynb: call to output_notebook() ignored when running notebooks with the 'bokeh' command.
# 2023-05-17 08:26:26,430 /Users/luca/Desktop/group-3/EPL Dashboard/Untitled.ipynb: call to show() ignored when running notebooks with the 'bokeh' command.
# 2023-05-17 08:26:26,432 Error running application handler <bokeh.application.handlers.notebook.NotebookHandler object at 0x7fe9605edfd0>: name 'get_ipython' is not defined
# File 'Untitled.ipynb', line 53, in <module>:
# "    const script = document.createElement(\"script\");\n", Traceback (most recent call last):
#   File "/Users/luca/opt/anaconda3/envs/visual-analytics/lib/python3.9/site-packages/bokeh/application/handlers/code_runner.py", line 231, in run
#     exec(self._code, module.__dict__)
#   File "/Users/luca/Desktop/group-3/EPL Dashboard/Untitled.ipynb", line 53, in <module>
#     "    const script = document.createElement(\"script\");\n",
# NameError: name 'get_ipython' is not defined
#
# 2023-05-17 08:26:26,578 WebSocket connection opened
# 2023-05-17 08:26:26,578 ServerConnection created
# 2023-05-17 08:26:31,021 WebSocket connection closed: code=1001, reason=None
# ^C
#
# Interrupted, shutting down
